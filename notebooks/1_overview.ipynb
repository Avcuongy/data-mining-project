# %% [markdown]
# # Payments

# %% [markdown]
# | Cột | Mô tả | Kiểu dữ liệu | Ví dụ |
# |---|---|---|---|
# | order_id | Mã định danh duy nhất của mỗi đơn hàng. | string | b81ef226f3fe1789b1e8b2acac839d17 |
# | payment_sequential | Thứ tự của lần thanh toán trong cùng một đơn hàng. Một đơn hàng có thể được thanh toán bằng nhiều phương thức khác nhau nên sẽ có nhiều sequence tương ứng. | integer | 1 |
# | payment_type | Phương thức thanh toán được khách hàng sử dụng cho đơn hàng. | string | credit_card |
# | payment_installments | Số kỳ thanh toán trả góp mà khách hàng lựa chọn. | integer | 8 |
# | payment_value | Giá trị giao dịch/thanh toán của đơn hàng. | float | 99.90 |

# %% [markdown]
# # Customers

# %% [markdown]
# | Cột | Mô tả | Kiểu dữ liệu | Ví dụ |
# |---|---|---|---|
# | customer_id | Khóa liên kết với bảng orders. Mỗi đơn hàng sẽ có một `customer_id` duy nhất. | string | 06b8999e2fba1a1fbc88172c00ba8bc7 |
# | customer_unique_id | Mã định danh duy nhất của khách hàng. Một khách hàng có thể thực hiện nhiều đơn hàng khác nhau. | string | 861eff4711a542e4b93843c6dd7febb0 |
# | customer_zip_code_prefix | 5 chữ số đầu của mã ZIP code của khách hàng. | integer | 14409 |
# | customer_city | Tên thành phố của khách hàng. | string | franca |
# | customer_state | Bang/tiểu bang của khách hàng. | string | SP |

# %% [markdown]
# # Items

# %% [markdown]
# | Cột | Mô tả | Kiểu dữ liệu | Ví dụ |
# |---|---|---|---|
# | order_id | Mã định danh duy nhất của đơn hàng. | string | 00010242fe8c5a6d1ba2dd792cb16214 |
# | order_item_id | Số thứ tự của sản phẩm trong cùng một đơn hàng. Dùng để phân biệt nhiều sản phẩm thuộc cùng một order. | integer | 1 |
# | product_id | Mã định danh duy nhất của sản phẩm. | string | 4244733e06e7ecb4970a6e2683c13e61 |
# | seller_id | Mã định danh duy nhất của người bán. | string | 48436dade18ac8b2bce089ec2a041202 |
# | shipping_limit_date | Thời hạn mà người bán phải bàn giao đơn hàng cho đối tác vận chuyển. | datetime | 2017-09-19 09:45:35 |
# | price | Giá của sản phẩm trong đơn hàng. | float | 58.90 |
# | freight_value | Chi phí vận chuyển của sản phẩm. Nếu đơn hàng có nhiều sản phẩm thì phí vận chuyển sẽ được chia cho từng sản phẩm. | float | 13.29 |

# %% [markdown]
# # Products

# %% [markdown]
# | Cột | Mô tả | Kiểu dữ liệu | Ví dụ |
# |---|---|---|---|
# | product_id | Mã định danh duy nhất của sản phẩm. | string | 1e9e8ef04dbcff4541ed26657ea517e5 |
# | product_category_name | Danh mục gốc của sản phẩm (được ghi bằng tiếng Bồ Đào Nha). | string | perfumaria |
# | product_name_lenght | Số lượng ký tự trong tên sản phẩm. | float | 40.0 |
# | product_description_lenght | Số lượng ký tự trong mô tả sản phẩm. | float | 287.0 |
# | product_photos_qty | Số lượng hình ảnh được đăng cho sản phẩm. | float | 1.0 |
# | product_weight_g | Khối lượng sản phẩm, tính bằng gram. | float | 225.0 |
# | product_length_cm | Chiều dài sản phẩm, tính bằng centimet. | float | 16.0 |
# | product_height_cm | Chiều cao sản phẩm, tính bằng centimet. | float | 10.0 |
# | product_width_cm | Chiều rộng sản phẩm, tính bằng centimet. | float | 14.0 |

# %% [markdown]
# # Orders

# %% [markdown]
# | Cột | Mô tả | Kiểu dữ liệu | Ví dụ |
# |---|---|---|---|
# | order_id | Mã định danh duy nhất của đơn hàng. | string | e481f51cbdc54678b7cc49136f2d6af7 |
# | customer_id | Khóa liên kết với bảng customer. Mỗi đơn hàng sẽ có một `customer_id` duy nhất. | string | 9ef432eb6251297304e76186b10a928d |
# | order_status | Trạng thái của đơn hàng (ví dụ: delivered, shipped, canceled,...). | string | delivered |
# | order_purchase_timestamp | Thời điểm khách hàng thực hiện mua hàng. | datetime | 2017-10-02 10:56:33 |
# | order_approved_at | Thời điểm thanh toán của đơn hàng được xác nhận. | datetime | 2017-10-02 11:07:15 |
# | order_delivered_carrier_date | Thời điểm đơn hàng được bàn giao cho đối tác vận chuyển. | datetime | 2017-10-04 19:55:00 |
# | order_delivered_customer_date | Thời điểm thực tế khách hàng nhận được đơn hàng. | datetime | 2017-10-10 21:25:13 |
# | order_estimated_delivery_date | Ngày giao hàng dự kiến được thông báo cho khách hàng tại thời điểm mua hàng. | datetime | 2017-10-18 00:00:00 |

# %% [markdown]
# # Sellers

# %% [markdown]
# | Cột | Mô tả | Kiểu dữ liệu | Ví dụ |
# |---|---|---|---|
# | seller_id | Mã định danh duy nhất của người bán. | string | 3442f8959a84dea7ee197c632cb2df15 |
# | seller_zip_code_prefix | 5 chữ số đầu của mã ZIP code của người bán. | integer | 13023 |
# | seller_city | Tên thành phố của người bán. | string | campinas |
# | seller_state | Bang/tiểu bang của người bán. | string | SP |
